# %% [markdown]
# # Wahadło na sprężynie <a class="tocSkip">

# %% [markdown]
# <img src="pliki/rysunki/wahadlo.png" alt="Girl in a jacket">

# %% [markdown]
# ## Generowanie spisu treści <a class="tocSkip">

# %% [markdown]
# Użyliśmy rozszerzecnia `Table of Contents (2)` (`toc2`). Otworzyliśmy spis treści i użyliśmy bardzo przydatnej funkcji przeglądarki - `zbadaj element`. Skopiowaliśmy cały `div` z zawartością spisu (wklejając w `''` które nie były użyte w kodzie `html`)

# %%
txt=r'<div id="toc" class="toc"><ul class="toc-item"><li><span class="highlight_on_scroll"><i class="fa fa-fw fa-caret-down"></i><a href="#Wprowadzenie" data-toc-modified-id="Wprowadzenie-1" class=""><span class="toc-item-num">1&nbsp;&nbsp;</span>Wprowadzenie</a></span><ul class="toc-item"><li><span class=""><i class="fa fa-fw"></i><a href="#Założenia:" data-toc-modified-id="Założenia:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Założenia:</a></span></li><li><span class=""><i class="fa fa-fw fa-caret-down"></i><a href="#Energia-w-układzie:" data-toc-modified-id="Energia-w-układzie:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Energia w układzie:</a></span><ul class="toc-item"><li><span><i class="fa fa-fw"></i><a href="#Energia-kinetyczna" data-toc-modified-id="Energia-kinetyczna-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Energia kinetyczna</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Energia-potencjalna" data-toc-modified-id="Energia-potencjalna-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Energia potencjalna</a></span></li></ul></li><li><span class=""><i class="fa fa-fw fa-caret-down"></i><a href="#Współrzędne-biegunowe" data-toc-modified-id="Współrzędne-biegunowe-1.3" class=""><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Współrzędne biegunowe</a></span><ul class="toc-item"><li><span class=""><i class="fa fa-fw"></i><a href="#Energia-Kinetyczna" data-toc-modified-id="Energia-Kinetyczna-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Energia Kinetyczna</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Energia-Potencjalna" data-toc-modified-id="Energia-Potencjalna-1.3.2" class=""><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Energia Potencjalna</a></span></li></ul></li><li><span><i class="fa fa-fw"></i><a href="#Wykresy-Energii-Potencjalnej" data-toc-modified-id="Wykresy-Energii-Potencjalnej-1.4" class=""><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Wykresy Energii Potencjalnej</a></span></li></ul></li><li><span><i class="fa fa-fw fa-caret-down"></i><a href="#Układ-równań" data-toc-modified-id="Układ-równań-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Układ równań</a></span><ul class="toc-item"><li><span><i class="fa fa-fw fa-caret-down"></i><a href="#Lagranżian-we-współrzędnych-biegunowych" data-toc-modified-id="Lagranżian-we-współrzędnych-biegunowych-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Lagranżian we współrzędnych biegunowych</a></span><ul class="toc-item"><li><span><i class="fa fa-fw"></i><a href="#Energia-Kinetyczna" data-toc-modified-id="Energia-Kinetyczna-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Energia Kinetyczna</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Energia-Potencjalna" data-toc-modified-id="Energia-Potencjalna-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Energia Potencjalna</a></span></li></ul></li><li><span><i class="fa fa-fw"></i><a href="#Lagrangian-we-współrzędnych-kartezjańskich" data-toc-modified-id="Lagrangian-we-współrzędnych-kartezjańskich-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Lagrangian we współrzędnych kartezjańskich</a></span></li></ul></li><li><span><i class="fa fa-fw fa-caret-down"></i><a href="#Linearyzacja" data-toc-modified-id="Linearyzacja-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Linearyzacja</a></span><ul class="toc-item"><li><span><i class="fa fa-fw"></i><a href="#Małe-wychylenia" data-toc-modified-id="Małe-wychylenia-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Małe wychylenia</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Małe-rozciągnięcia-sprężyny" data-toc-modified-id="Małe-rozciągnięcia-sprężyny-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Małe rozciągnięcia sprężyny</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Małe-prędkości" data-toc-modified-id="Małe-prędkości-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Małe prędkości</a></span></li></ul></li><li><span><i class="fa fa-fw"></i><a href="#Rozwiązanie-analityczne-równania-liniowego" data-toc-modified-id="Rozwiązanie-analityczne-równania-liniowego-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Rozwiązanie analityczne równania liniowego</a></span></li><li><span><i class="fa fa-fw fa-caret-down"></i><a href="#Rozwiązanie-numeryczne" data-toc-modified-id="Rozwiązanie-numeryczne-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Rozwiązanie numeryczne</a></span><ul class="toc-item"><li><span><i class="fa fa-fw"></i><a href="#Gauss" data-toc-modified-id="Gauss-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Gauss</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Porównanie-metod-numerycznych" data-toc-modified-id="Porównanie-metod-numerycznych-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Porównanie metod numerycznych</a></span></li><li><span><i class="fa fa-fw fa-caret-down"></i><a href="#Porównanie-rozwiązania-liniowego" data-toc-modified-id="Porównanie-rozwiązania-liniowego-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Porównanie rozwiązania liniowego</a></span><ul class="toc-item"><li><span><i class="fa fa-fw"></i><a href="#Znalezienie-stałych-dla-$r$" data-toc-modified-id="Znalezienie-stałych-dla-$r$-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Znalezienie stałych dla $r$</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Znalezienie-stałych-dla-$\theta$" data-toc-modified-id="Znalezienie-stałych-dla-$\theta$-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Znalezienie stałych dla $\theta$</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Porównanie--na-wykresach" data-toc-modified-id="Porównanie--na-wykresach-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Porównanie  na wykresach</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Wykresy-dla-różnych-wartości-$\dfrac{m}{k}$" data-toc-modified-id="Wykresy-dla-różnych-wartości-$\dfrac{m}{k}$-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Wykresy dla różnych wartości $\dfrac{m}{k}$</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Animacja" data-toc-modified-id="Animacja-5.3.5"><span class="toc-item-num">5.3.5&nbsp;&nbsp;</span>Animacja</a></span></li></ul></li></ul></li><li><span><i class="fa fa-fw fa-caret-down"></i><a href="#Doświadczenie" data-toc-modified-id="Doświadczenie-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Doświadczenie</a></span><ul class="toc-item"><li><span><i class="fa fa-fw"></i><a href="#stała-sprężystości" data-toc-modified-id="stała-sprężystości-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>stała sprężystości</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Obliczenia" data-toc-modified-id="Obliczenia-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Obliczenia</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Porównanie-z-eksperymentem" data-toc-modified-id="Porównanie-z-eksperymentem-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Porównanie z eksperymentem</a></span></li><li><span><i class="fa fa-fw"></i><a href="#Tor-ruchu-innych-dośwadczeń" data-toc-modified-id="Tor-ruchu-innych-dośwadczeń-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Tor ruchu innych dośwadczeń</a></span></li></ul></li><li><span><i class="fa fa-fw"></i><a href="#Bibliografia" data-toc-modified-id="Bibliografia-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Bibliografia</a></span></li></ul></div>'

# %% [markdown]
# I usunęliśmy wszystkie wyrazy `toc` z niego (oraz parę `class` by spis się nie świecił)

# %%
i=0
out=""
while True:
    if i >=len(txt):
        break
        
    if txt[i]=="t":
        if txt[i:i+3]=="toc":
            i+=3
            continue
            
    # Usuwanie podświetleń
    if txt[i]=="<":
        if txt[i:i+34]=='<i class="fa fa-fw fa-caret-down">':
            i+=34
            continue
        if txt[i:i+24]=='<i class="fa fa-fw"></i>':
            i+=24
            continue
        if txt[i:i+34]=='<span class="highlight_on_scroll">':
            i+=34
            continue
            
    # Usuwanie nadprogramowych odstępów
    if txt[i]=='&':
        if txt[i:i+6]=='&nbsp;':
            if txt[i+6:i+6+6]=='&nbsp;':
                i+=6
                continue
    
    out+=txt[i]
    i+=1
print(out)
# Out:
# <div id="" class=""><ul class="-item"><li></i><a href="#Wprowadzenie" data--modified-id="Wprowadzenie-1" class=""><span class="-item-num">1&nbsp;</span>Wprowadzenie</a></span><ul class="-item"><li><span class=""><a href="#Założenia:" data--modified-id="Założenia:-1.1"><span class="-item-num">1.1&nbsp;</span>Założenia:</a></span></li><li><span class=""></i><a href="#Energia-w-układzie:" data--modified-id="Energia-w-układzie:-1.2"><span class="-item-num">1.2&nbsp;</span>Energia w układzie:</a></span><ul class="-item"><li><span><a href="#Energia-kinetyczna" data--modified-id="Energia-kinetyczna-1.2.1"><span class="-item-num">1.2.1&nbsp;</span>Energia kinetyczna</a></span></li><li><span><a href="#Energia-potencjalna" data--modified-id="Energia-potencjalna-1.2.2"><span class="-item-num">1.2.2&nbsp;</span>Energia potencjalna</a></span></li></ul></li><li><span class=""></i><a href="#Współrzędne-biegunowe" data--modified-id="Współrzędne-biegunowe-1.3" class=""><span class="-item-num">1.3&nbs
# ...

# %% [markdown]
# To co otrzymaliśmy to jest nasz zaktualizowany spis treści

# %% [markdown]
# ## Table of Contents<a class="tocSkip">

# %% [markdown]
# <div id="" class=""><ul class="-item"><li></i><a href="#Wprowadzenie" data--modified-id="Wprowadzenie-1" class=""><span class="-item-num">1&nbsp;</span>Wprowadzenie</a></span><ul class="-item"><li><span class=""><a href="#Założenia:" data--modified-id="Założenia:-1.1"><span class="-item-num">1.1&nbsp;</span>Założenia:</a></span></li><li><span class=""></i><a href="#Energia-w-układzie:" data--modified-id="Energia-w-układzie:-1.2"><span class="-item-num">1.2&nbsp;</span>Energia w układzie:</a></span><ul class="-item"><li><span><a href="#Energia-kinetyczna" data--modified-id="Energia-kinetyczna-1.2.1"><span class="-item-num">1.2.1&nbsp;</span>Energia kinetyczna</a></span></li><li><span><a href="#Energia-potencjalna" data--modified-id="Energia-potencjalna-1.2.2"><span class="-item-num">1.2.2&nbsp;</span>Energia potencjalna</a></span></li></ul></li><li><span class=""></i><a href="#Współrzędne-biegunowe" data--modified-id="Współrzędne-biegunowe-1.3" class=""><span class="-item-num">1.3&nbsp;</span>Współrzędne biegunowe</a></span><ul class="-item"><li><span class=""><a href="#Energia-Kinetyczna" data--modified-id="Energia-Kinetyczna-1.3.1"><span class="-item-num">1.3.1&nbsp;</span>Energia Kinetyczna</a></span></li><li><span><a href="#Energia-Potencjalna" data--modified-id="Energia-Potencjalna-1.3.2" class=""><span class="-item-num">1.3.2&nbsp;</span>Energia Potencjalna</a></span></li></ul></li><li><span><a href="#Wykresy-Energii-Potencjalnej" data--modified-id="Wykresy-Energii-Potencjalnej-1.4" class=""><span class="-item-num">1.4&nbsp;</span>Wykresy Energii Potencjalnej</a></span></li></ul></li><li><span></i><a href="#Układ-równań" data--modified-id="Układ-równań-2"><span class="-item-num">2&nbsp;</span>Układ równań</a></span><ul class="-item"><li><span></i><a href="#Lagranżian-we-współrzędnych-biegunowych" data--modified-id="Lagranżian-we-współrzędnych-biegunowych-2.1"><span class="-item-num">2.1&nbsp;</span>Lagranżian we współrzędnych biegunowych</a></span><ul class="-item"><li><span><a href="#Energia-Kinetyczna" data--modified-id="Energia-Kinetyczna-2.1.1"><span class="-item-num">2.1.1&nbsp;</span>Energia Kinetyczna</a></span></li><li><span><a href="#Energia-Potencjalna" data--modified-id="Energia-Potencjalna-2.1.2"><span class="-item-num">2.1.2&nbsp;</span>Energia Potencjalna</a></span></li></ul></li><li><span><a href="#Lagrangian-we-współrzędnych-kartezjańskich" data--modified-id="Lagrangian-we-współrzędnych-kartezjańskich-2.2"><span class="-item-num">2.2&nbsp;</span>Lagrangian we współrzędnych kartezjańskich</a></span></li></ul></li><li><span></i><a href="#Linearyzacja" data--modified-id="Linearyzacja-3"><span class="-item-num">3&nbsp;</span>Linearyzacja</a></span><ul class="-item"><li><span><a href="#Małe-wychylenia" data--modified-id="Małe-wychylenia-3.1"><span class="-item-num">3.1&nbsp;</span>Małe wychylenia</a></span></li><li><span><a href="#Małe-rozciągnięcia-sprężyny" data--modified-id="Małe-rozciągnięcia-sprężyny-3.2"><span class="-item-num">3.2&nbsp;</span>Małe rozciągnięcia sprężyny</a></span></li><li><span><a href="#Małe-prędkości" data--modified-id="Małe-prędkości-3.3"><span class="-item-num">3.3&nbsp;</span>Małe prędkości</a></span></li></ul></li><li><span><a href="#Rozwiązanie-analityczne-równania-liniowego" data--modified-id="Rozwiązanie-analityczne-równania-liniowego-4"><span class="-item-num">4&nbsp;</span>Rozwiązanie analityczne równania liniowego</a></span></li><li><span></i><a href="#Rozwiązanie-numeryczne" data--modified-id="Rozwiązanie-numeryczne-5"><span class="-item-num">5&nbsp;</span>Rozwiązanie numeryczne</a></span><ul class="-item"><li><span><a href="#Gauss" data--modified-id="Gauss-5.1"><span class="-item-num">5.1&nbsp;</span>Gauss</a></span></li><li><span><a href="#Porównanie-metod-numerycznych" data--modified-id="Porównanie-metod-numerycznych-5.2"><span class="-item-num">5.2&nbsp;</span>Porównanie metod numerycznych</a></span></li><li><span></i><a href="#Porównanie-rozwiązania-liniowego" data--modified-id="Porównanie-rozwiązania-liniowego-5.3"><span class="-item-num">5.3&nbsp;</span>Porównanie rozwiązania liniowego</a></span><ul class="-item"><li><span><a href="#Znalezienie-stałych-dla-$r$" data--modified-id="Znalezienie-stałych-dla-$r$-5.3.1"><span class="-item-num">5.3.1&nbsp;</span>Znalezienie stałych dla $r$</a></span></li><li><span><a href="#Znalezienie-stałych-dla-$\theta$" data--modified-id="Znalezienie-stałych-dla-$\theta$-5.3.2"><span class="-item-num">5.3.2&nbsp;</span>Znalezienie stałych dla $\theta$</a></span></li><li><span><a href="#Porównanie--na-wykresach" data--modified-id="Porównanie--na-wykresach-5.3.3"><span class="-item-num">5.3.3&nbsp;</span>Porównanie  na wykresach</a></span></li><li><span><a href="#Wykresy-dla-różnych-wartości-$\dfrac{m}{k}$" data--modified-id="Wykresy-dla-różnych-wartości-$\dfrac{m}{k}$-5.3.4"><span class="-item-num">5.3.4&nbsp;</span>Wykresy dla różnych wartości $\dfrac{m}{k}$</a></span></li><li><span><a href="#Animacja" data--modified-id="Animacja-5.3.5"><span class="-item-num">5.3.5&nbsp;</span>Animacja</a></span></li></ul></li></ul></li><li><span></i><a href="#Doświadczenie" data--modified-id="Doświadczenie-6"><span class="-item-num">6&nbsp;</span>Doświadczenie</a></span><ul class="-item"><li><span><a href="#stała-sprężystości" data--modified-id="stała-sprężystości-6.1"><span class="-item-num">6.1&nbsp;</span>stała sprężystości</a></span></li><li><span><a href="#Obliczenia" data--modified-id="Obliczenia-6.2"><span class="-item-num">6.2&nbsp;</span>Obliczenia</a></span></li><li><span><a href="#Porównanie-z-eksperymentem" data--modified-id="Porównanie-z-eksperymentem-6.3"><span class="-item-num">6.3&nbsp;</span>Porównanie z eksperymentem</a></span></li><li><span><a href="#Tor-ruchu-innych-dośwadczeń" data--modified-id="Tor-ruchu-innych-dośwadczeń-6.4"><span class="-item-num">6.4&nbsp;</span>Tor ruchu innych dośwadczeń</a></span></li></ul></li><li><span><a href="#Bibliografia" data--modified-id="Bibliografia-7"><span class="-item-num">7&nbsp;</span>Bibliografia</a></span></li></ul></div>

# %% [markdown]
# # Wprowadzenie

# %% [markdown]
# Tematem naszego projeku jest Wahadło nieliniowe. Na sprężynie umieściliściliśmy ciało, które następnie wychyliliśmy, naciągnęliśmy sprężynę i nadaliśmy mu prędkości początkowe. Jest to naturalne uogólnienie wahadła prostego, gdzie uznajemy, że ramie na którym zawieszone jest ciało może się rozciągać (przykładowo dla nitki współczynnik sprężystości jest bardzo duży, co powoduje zaniedbywalne zmiany jej długości).

# %% [markdown]
# W dalszej części często pojawiają się 3 animacje tej samej sytuacji (1. Sam tor ruchu, 2. z zaznaczonym aktualnym położeniem ciała, 3. oraz z uproszczonym położeniem sprężyny). Zdecydowaliśmy się trzykrotnie zamieścić ten sam wykres, ponieważ każdy następny potrzebuje coraz więcej mocy obliczeniowej, ponieważ każdorazowo trzeba rysować go od początku, co czasem znacznie spowalnia animacje.

# %% [markdown]
# ## Założenia:

# %% [markdown]
# - sprężyna się nie wygina
# - brak oporów ruchu
# - Ruch jest wzdłuż jednej płaszczyzny (zmienia się kąt oraz długość sprężyny)
# - Masa sprężyny jest pomijalna
# - Całkowita energia układu składa się z energi kinetycznej i potencjalnej ciała oraz energi potencjalnej sprężyny
# - Układ jest izolowany (nie działają siły zewnętrzne)

# %% [markdown]
# ## Energia w układzie:

# %% [markdown]
# ### Energia kinetyczna

# %% [markdown]
# $$ T = \frac{mv^2}{2} = \frac{m\dot{\gamma}^2}{2} = \frac{m(\dot{x}^2+\dot{y}^2)}{2}=\frac{m(\dot{r}^2+r^2\dot{\theta}^2)}{2}$$

# %% [markdown]
# ### Energia potencjalna

# %% [markdown]
# - Grawitacji
# $$ U_g = mgh$$
# - Sprężyny
# $$ U_s = \frac{1}{2}k \left(l-r\right)^2$$
# Gdzie
#  - $m$ - masza ciała (kulki)
#  - $v=v(t)$ - prędkość ciała (kulki) w chwili t
#  - $\gamma = \gamma(t)$ - położeniem ciała (kulki) w chwili t
#  - $g$ - stała grawitacyjna
#  - $h=h(t)$ - wysokość ciała (kulki) nad pewnym poziomem w chwili t
#  - $r=r(t)$ - długość sprężyny w chwili t
#  - $\theta$ - kąt wychylenia z pionu sprężyny
#  - $l$ - długość sprężyny w spoczynku

# %% [markdown]
# ## Współrzędne biegunowe

# %% [markdown]
# Jeśli przyjmiemy, że
#  - $r$ jest rozciągnięciem sprężyny ( $l+r$ jest długością sprężyny)
#  - $\theta$ kątem między sprężyną a położeniem równowagi (pionem)
#
# (jak na rysunku poniżej)

# %% [markdown]
# <img src="pliki/rysunki/wahadlo_energia.png" alt="Girl in a jacket" width="800">

# %% [markdown]
# to powyższe wzory możemy przepisać w następujący sposób

# %% [markdown]
# ### Energia Kinetyczna

# %% [markdown]
# $$ T = \frac{mv^2}{2} =\frac{m\left({\left(\dot l+\dot r\right)}^2+(l+r)^2\dot{\theta}^2\right)}{2} = \frac{m\left({\dot r}^2+(l+r)^2\dot{\theta}^2\right)}{2}$$

# %% [markdown]
# ### Energia Potencjalna

# %% [markdown]
# - Grawitacji <br>
# $$ U_g = {mg}h = {mg}\left(l-(l+r)\cos\theta\right) = mgl - mg(l+r)\cos\theta = mg(l+r)(1-\cos\theta) - mgr$$
# - Sprężyny
# $$ U_s = \frac{1}{2}kr^2$$

# %% [markdown]
# ## Wykresy Energii Potencjalnej

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')
# %matplotlib inline

def U(x,y,l=1,m=1,k=1): # Energia potencjalna w współrzędnych kartezjańskich
    g=9.81
    Us=1/2*k*(l-(x**2+y**2)**(1/2))**2
    Uc=m*g*(l-y)
    return Us+Uc

# %%
n=200
E=[[U(x,-y,k=20) for x in np.linspace(-1,1,n)] for y in np.linspace(-1,1,n)]

plt.contour(np.linspace(-1,1,n),np.linspace(-1,1,n),E)

# %%
n=200
E=[[U(x,-y,k=20) for x in np.linspace(-1,1,n)] for y in np.linspace(-1,1,n)]

fig, ax = plt.subplots()
CS = ax.contour(np.linspace(-1,1,n),np.linspace(-1,1,n),E, levels=[0,3,5,9,13,14,15,16,17,17.5,18])
ax.clabel(CS, inline=1,fontsize=10)
# Out:
# <a list of 12 text.Text objects>

# %%
n=200*2
E=[[U(x,-y,k=20) for x in np.linspace(-2,2,n)] for y in np.linspace(-2,1,n)]

fig, ax = plt.subplots()
CS = ax.contour(np.linspace(-2,2,n),np.linspace(-2,1,n),E, levels=[-2,0,3,5,9,13,15,17.5,20])
ax.clabel(CS, inline=1,fontsize=10)
# Out:
# <a list of 13 text.Text objects>

# %%
n=200
lim=np.linspace(-1.5,1.5,n)
E=[[U(x,-y,k=50) for x in lim] for y in lim]

fig, ax = plt.subplots()
CS = ax.contour(lim,lim,E,levels=[-0.7,0,8,16,18.66,24,32])
ax.clabel(CS, inline=1,fontsize=10)
# Out:
# <a list of 12 text.Text objects>

# %% [markdown]
# # Układ równań

# %% [markdown]
# Dzięki naszym genialnym fizykom wiemy, że różnica między energią kinetyczną, a energią potencjalną ma wiele użyteczynych własności. Ta różnica została nazwana Lagranżianem
# $$\mathcal{L} = T - U .$$
# Dla nas szczególnie użyteczne będzie jedna własność, a mianowicie dla każdego $q_i$

# %% [markdown]
# $$ \frac{\partial{\mathcal{L}}}{\partial{q_i}}=\frac{\text d}{\text d t} \frac{\partial{\mathcal{L}}}{\partial\dot{q_i}}$$

# %% [markdown]
# gdzie $q_i$ jest i-tą zmienną. Zatem w naszym przypadku

# %% [markdown]
# ## Lagranżian we współrzędnych biegunowych

# %% [markdown]
# $$\mathcal{L} = T - U = T - U_c - U_s = \frac{m\left({\dot r}^2+(l+r)^2\dot{\theta}^2\right)}{2} - mg(l+r)(1-\cos\theta) + mgr - \dfrac{k}{2}r^2$$

# %% [markdown]
# Wiemy, że
# $$ \frac{\partial{\mathcal{L}}}{\partial{r}}=\frac{\text d}{\text d t} \frac{\partial{\mathcal{L}}}{\partial\dot{r}} \quad \text{oraz} \quad \frac{\partial{\mathcal{L}}}{\partial{\theta}}=\frac{\text d}{\text d t} \frac{\partial{\mathcal{L}}}{\partial\dot{\theta}}$$

# %% [markdown]
# Co daje nam dwa równania
# $$
# \left\{
# \begin{array}{l}
# m(l+r)\dot{\theta}^2 - kr - mg(1-\cos\theta) + mg = \frac{\text d}{\text d t}\left(\vphantom{\frac{\text d}{\text d t}}m\dot r\right)\\
# -\sin\theta mg(l+r) = \frac{\text d}{\text d t}\left(\vphantom{\frac{\text d}{\text d t}}m(l+r)^2\dot\theta\right)
# \end{array} \right.
# $$

# %% [markdown]
# Które po przekształceniach przyjmują postać
# $$
# \left\{ \begin{array}{l}
# \ddot{r}= g \cos\theta - \frac{k}{m}r+(l+r)\dot\theta^2\\
# \ddot{\theta}(l+r) = -g\sin\theta - 2 \dot\theta\dot{r}
# \end{array} \right.
# $$

# %% [markdown]
# Ale, co zaskakujące, we współrzędnych <b>kartezjańskich</b>, równanie to przyjmuję bardzo przyjemną formę.

# %% [markdown]
# ## Lagrangian we współrzędnych kartezjańskich

# %% [markdown]
# ### Energia Kinetyczna

# %% [markdown]
# $$ T = \frac{mv^2}{2} =\frac{m\left(\dot x^2 +\dot y^2\right)}{2}$$

# %% [markdown]
# ### Energia Potencjalna

# %% [markdown]
# - Ciała
# $$ U_c = mgh = mg(l-y) = -mgy$$
# - Sprężyny
# $$ U_s = \frac{1}{2}k(l-r)=\frac{1}{2}k\left(l-\sqrt{x^2+y^2}\right)^2$$

# %% [markdown]
# $$\mathcal{L} = T - U = T - U_c - U_s = \frac{m\left(\dot x^2 +\dot y^2\right)}{2} + mgy -\frac{1}{2}k\left(l-\sqrt{x^2+y^2}\right)^2$$

# %% [markdown]
# ### Postać równania

# %% [markdown]
# Ponownie wiemy, że
# $$ \frac{\partial{\mathcal{L}}}{\partial{x}}=\frac{\text d}{\text d t} \frac{\partial{\mathcal{L}}}{\partial\dot{x}} \quad \text{oraz} \quad \frac{\partial{\mathcal{L}}}{\partial{y}}=\frac{\text d}{\text d t} \frac{\partial{\mathcal{L}}}{\partial\dot{y}}$$

# %% [markdown]
# Co daje nam dwa równania
# $$
# \left\{
# \begin{array}{l}
# -k\left(l-\sqrt{x^2+y^2}\right)\dfrac{x}{\sqrt{x^2+y^2}} = \dfrac{\text d}{\text d t}\left(\vphantom{\dfrac{\text d}{\text d t}} m\dot x\right)\\
# mg-k\left(l-\sqrt{x^2+y^2}\right)\dfrac{y}{\sqrt{x^2+y^2}}=\dfrac{\text d}{\text d t}\left(\vphantom{\dfrac{\text d}{\text d t}} m\dot y\right)
# \end{array} \right.
# $$

# %% [markdown]
# Które po przekształceniach przyjmują postać
# $$
# \left\{ \begin{array}{l}
# \ddot{x}= \phantom{g+}x\dfrac{-k}{m}\left(1-\dfrac{l}{\sqrt{x^2+y^2}}\right)\\
# \ddot{y}= g+y\dfrac{-k}{m}\left(1-\dfrac{l}{\sqrt{x^2+y^2}}\right)\\
# \end{array} \right.
# $$

# %% [markdown]
# Możemy zauważyć pewne podobieństwo między równaniami, jeśli przyjmiemy, że

# %% [markdown]
# $$ f(x,y) = \dfrac{-k}{m}\left(1-\dfrac{l}{\sqrt{x^2+y^2}}\right) $$

# %% [markdown]
# Powyższy układ równanań przyjmuje postać
# $$
# \left\{ \begin{array}{l}
# \ddot{x}=\phantom{g+} xf(x,y)\\
# \ddot{y}= g+yf(x,y)\\
# \end{array} \right.
# $$

# %% [markdown]
# My będziemy je jednak rozpatrywać we współrzędnych biegunowych z powodu łatwiejszego wyboru, interpretacji warunków początkowych

# %% [markdown]
# # Linearyzacja

# %% [markdown]
# Spróbujmy teraz zlinearyzować, nasze równanie. Najlepiej będzie do tego wykorzystać nasz układ równań we współrzednych biegunowych, które przyjmują postać

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# \ddot{r}= g \cos\theta - \frac{k}{m}r+(l+r)\dot\theta^2\\
# \ddot{\theta}(l+r) = -g\sin\theta + 2 \dot\theta\dot{r}
# \end{array} \right.
# $$

# %% [markdown]
# ## Małe wychylenia

# %% [markdown]
# Jeśli założymy, że maksymalne wychylenie z położenia równowagi jest małe (powiedzmy $\theta<6^{\circ}$), to możemy przybliżać
# $$ \sin\theta\approx\theta$$
# $$ \cos\theta\approx 1 $$

# %% [markdown]
# Nasz układ równań przyjmuje, że postać

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# \ddot{r}= g - \frac{k}{m}r+(l+r)\dot\theta^2\\
# \ddot{\theta}(l+r) = -g\theta + 2 \dot\theta\dot{r}
# \end{array} \right.
# $$

# %% [markdown]
# Jednak nadal daleko stąd do liniowości.

# %% [markdown]
# ## Małe rozciągnięcia sprężyny

# %% [markdown]
# Uznajmy jeszcze, że sprężyna rozciąga się niewiele w porównaniu do długości ($r\ll l$), wtedy

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# \ddot{r}= g - \frac{k}{m}r+l\dot\theta^2\\
# \ddot{\theta}l = -g\theta + 2 \dot\theta\dot{r}
# \end{array} \right.
# $$

# %% [markdown]
# Niestety zostaje nam nieliniowość w postaci $2\dot\theta\dot r$.

# %% [markdown]
# ## Małe prędkości

# %% [markdown]
# By się pozbyć ostatniej nieliniowości przyjmijmy, że $\dot\theta$ oraz $\dot r$ również możemy zaniedbać. Po tych wszystkich uproszczeniach otrzymujemy układ równań liniowych, który jeśli podzielimy drugie przez $l$, przyjmuje postać

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# \ddot{r}= g - \frac{k}{m}r + l\dot\theta^2\\
# \ddot{\theta} = -\frac{g}{l}\theta
# \end{array} \right.
# $$

# %% [markdown]
# Które potrafimy rozwiązać analitycznie.

# %% [markdown]
# # Prawdziwe analityczne

# %% [markdown]
# Możemy zauważyć, że w układzie równań różniczkowych

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# \ddot{r}= g - \frac{k}{m}r + l\dot\theta^2\\
# \ddot{\theta} = -\frac{g}{l}\theta
# \end{array} \right.
# $$

# %% [markdown]
# $\theta$ nie zależy od $r$, więc zaczniemy od jej znalezienia.

# %% [markdown]
# ## Znalezienie $\theta$

# %% [markdown]
# Równanie

# %% [markdown]
# $$\ddot\theta + \frac{g}{l}\theta=0$$

# %% [markdown]
# jest jednorodnym i zwyczajnym równaniem różniczkowym drugiego rzędu o stałych współczynnikach. Do rozwiązania jego wystarczy nam urzyć wielomianu charakterystycznego

# %% [markdown]
# $$\lambda^2+\frac{g}{l}\lambda=0$$

# %% [markdown]
# Od razu widzimy, że powyższe równanie ma dwa pierwiastki zespolone $\lambda_0\in\left\{\pm i\sqrt\frac{g}{l}\right\}$, więc nasza $\theta$ ma rozwiązanie ogólne w postaci

# %% [markdown]
#  $$\theta=A_\theta\cos\sqrt\frac{g}{l}t +  B_\theta\sin\sqrt\frac{g}{l}t$$

# %% [markdown]
# ## Znalenienie $r$

# %% [markdown]
# Znaleźliśmy już postać $\theta$-ty, zatem wiemy jak wygląda już równanie na $r$

# %% [markdown]
# $$\ddot{r}= g - \frac{k}{m}r + l\dot\theta=g - \frac{k}{m}r + l\left(B_\theta\sqrt\frac{g}{l}\cos\sqrt\frac{g}{l}t-A_\theta\sqrt\frac{g}{l}\sin\sqrt\frac{g}{l}t\right)^2$$

# %% [markdown]
# Przepiszmy je w postaci

# %% [markdown]
# $$\ddot{r}+ \frac{k}{m}r=g + l\left(B_\theta\sqrt\frac{g}{l}\cos\sqrt\frac{g}{l}t-A_\theta\sqrt\frac{g}{l}\sin\sqrt\frac{g}{l}t\right)$$

# %% [markdown]
# $$\ddot{r}+ \frac{k}{m}r=g + B_\theta^2g\cos^2\sqrt\frac{g}{l}t+A_\theta^2g\sin^2\sqrt\frac{g}{l}t-2A_\theta B_\theta g \sin\sqrt\frac{g}{l}t\cos\sqrt\frac{g}{l}t$$

# %% [markdown]
# Otrzymaliśmy teraz równanie podobne jak dla $\theta$-ty ale z niejednorodnością.

# %% [markdown]
# ### Rozwiązanie jednorodne

# %% [markdown]
# Rozwiązanie jego rozpocznijmy od znalezienie rozwiązanie jednorodnego dla $r$. Równanie

# %% [markdown]
# $$\ddot{r}+ \frac{k}{m}r=0$$

# %% [markdown]
# Rozwiązujemy postępując tak samo jak podczas szukania w poprzednik podpunkcjie otrzymując

# %% [markdown]
#  $$r=A_t\cos\sqrt\frac{k}{m}t +  B_r\sin\sqrt\frac{k}{m}t+\varphi$$

# %% [markdown]
# gdzie $\varphi$ jest rozwiązaniem równania niejednorodnego.

# %% [markdown]
# ### Rozwiązanie niejednorodne

# %% [markdown]
# Równanie

# %% [markdown]
# $$\ddot{r}+ \frac{k}{m}r=g + B_\theta^2g\cos^2\sqrt\frac{g}{l}t+A_\theta^2g\sin^2\sqrt\frac{g}{l}t-2A_\theta B_\theta g \sin\sqrt\frac{g}{l}t\cos\sqrt\frac{g}{l}t$$

# %% [markdown]
# przepisaliśmy korzystając z tożsamości trygonometrycznych

# %% [markdown]
# $$\cos^2x=\frac{1+\cos2x}{2}$$
# $$\sin^2x=\frac{1-\cos2x}{2}$$
# $$\sin2x=2\sin x\cos x$$

# %% [markdown]
# i oprzymaliśmy

# %% [markdown]
# $$\ddot{r}+ \frac{k}{m}r=g + \frac{1}{2}B_\theta^2g\cos\left(2\sqrt\frac{g}{l}t\right)+\frac{1}{2}A_\theta^2g\cos\left(2\sqrt\frac{g}{l}t\right)-A_\theta B_\theta g \sin\left(2\sqrt\frac{g}{l}t\right)+\left(A_\theta^2 +  B_\theta^2\right)g$$

# %% [markdown]
# $$\ddot{r}+ \frac{k}{m}r=g\left(1+A_\theta^2 +  B_\theta^2\right) + \frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)g\cos\left(2\sqrt\frac{g}{l}t\right)-A_\theta B_\theta g \sin\left(2\sqrt\frac{g}{l}t\right)$$

# %% [markdown]
# Zanim zaczniemy szukać rozwiązania niejednorodnego, założyliśmy, że nie niejednorodność nie jest kombinacją liniową znalezionego już rozwiązania, czyli

# %% [markdown]
# $$\sqrt\frac{k}{m}\neq2\sqrt\frac{g}{l}.$$

# %% [markdown]
# Zatem, teraz możemy zapostulować, że nasze $\varphi$ jest w postaci

# %% [markdown]
# $$\varphi=C\cos\left(2\sqrt\frac{g}{l}t\right) +  D\sin\left(2\sqrt\frac{g}{l}t\right) + E.$$

# %% [markdown]
# Wtedy

# %% [markdown]
# $$\dot\varphi= -2C\sqrt\frac{g}{l}\sin\left(2\sqrt\frac{g}{l}t\right) +  2D\sqrt\frac{g}{l}\cos\left(2\sqrt\frac{g}{l}t\right)$$
# $$\ddot\varphi=-4C     \frac{g}{l}\cos\left(2\sqrt\frac{g}{l}t\right) -  4D     \frac{g}{l}\sin\left(2\sqrt\frac{g}{l}t\right)$$

# %% [markdown]
# Podstawiając je do równania na $r$ dostajemy potworka w postaci

# %% [markdown]
# $$ \ddot\varphi+\frac{k}{m}\varphi=-4C     \frac{g}{l}\cos\left(2\sqrt\frac{g}{l}t\right) -  4D     \frac{g}{l}\sin\left(2\sqrt\frac{g}{l}t\right) + \frac{k}{m}\left(C\cos\left(2\sqrt\frac{g}{l}t\right) +  D\sin\left(2\sqrt\frac{g}{l}t\right) + E\right)$$

# %% [markdown]
# $$\ddot\varphi+\frac{k}{m}\varphi=g\left(1+A_\theta^2 +  B_\theta^2\right) + \frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)g\cos\left(2\sqrt\frac{g}{l}t\right)-A_\theta B_\theta g \sin\left(2\sqrt\frac{g}{l}t\right),$$

# %% [markdown]
# z którego jeśli pogrupujemy wyrazy przy odpowiednich funkcjach otrzymamy

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# E\frac{k}{m}=\left(1+A_\theta^2 +  B_\theta^2\right)g\\
# -4C\frac{g}{l}+C\frac{k}{m}=\frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)g\\
# -4D\frac{g}{l}+D\frac{k}{m}=-A_\theta B_\theta g
# \end{array} \right.
# $$

# %% [markdown]
# Skąd łatwo już wyznaczyć współczynniki $C,D$ oraz $E$

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# E=\frac{mg}{k}\left(1+A_\theta^2 +  B_\theta^2\right)\\
# C=\frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)\frac{g}{\frac{k}{m}-4\frac{g}{l}}\\
# D=-A_\theta B_\theta\frac{g}{\frac{k}{m}-4\frac{g}{l}}
# \end{array} \right.
# $$

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# E=\frac{mg}{k}\left(1+A_\theta^2 +  B_\theta^2\right)\\
# C=\frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)\frac{gml}{kl-4gm}\\
# D=-A_\theta B_\theta\frac{gml}{kl-4gm}
# \end{array} \right.
# $$

# %% [markdown]
# Co już nie wygląda najładniej, ale dzięki temu otrzymujemy analityczny wzór na $r$

# %% [markdown]
#  $$r=A_r\cos\sqrt\frac{k}{m}t +  B_r\sin\sqrt\frac{k}{m}t+\frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)\frac{gml}{kl-4gm}\cos\left(2\sqrt\frac{g}{l}t\right) +  -A_\theta B_\theta\frac{gml}{kl-4gm}\sin\left(2\sqrt\frac{g}{l}t\right) + \frac{mg}{k}\left(1+A_\theta^2 +  B_\theta^2\right)$$

# %% [markdown]
#  $$r=A_r\cos\sqrt\frac{k}{m}t +  B_r\sin\sqrt\frac{k}{m}t+\frac{B_\theta\sqrt{gl}}{\frac{k}{m}-\frac{g}{l}}\cos\sqrt\frac{g}{l}t +  \frac{-A_\theta\sqrt{gl}}{\frac{k}{m}-\frac{g}{l}}\sin\sqrt\frac{g}{l}t + g\frac{m}{k}$$

# %% [markdown]
#  $$r=A_r\cos\sqrt\frac{k}{m}t +  B_r\sin\sqrt\frac{k}{m}t+\frac{B_\theta lm\sqrt{gl}}{kl-gm}\cos\sqrt\frac{g}{l}t - \frac{A_\theta ml\sqrt{gl}}{kl-gm}\sin\sqrt\frac{g}{l}t + g\frac{m}{k}$$

# %% [markdown]
# # Rozwiązanie analityczne równania liniowego

# %% [markdown]
# Widzimy, że oba równania są niezależne między sobą, dlatego możemy je rozważać osobno.
# $$\ddot{r}= g - \frac{k}{m}r \quad\quad \land \quad\quad \ddot{\theta} = -\frac{g}{l}\theta$$

# %% [markdown]
# Zacznijmy od $r$. Otrzymujemy równanie
# $$\ddot r+\frac{k}{m}r=g.$$

# %% [markdown]
# Jest to zwykłe równanie o stałych współczynnikach, ze stałą niejednorodnością. Pojawia się $r$ więc do rozwiązania jednorodnego wystarczy dodać $g*a^{-1}$, gdzie $a$ jest współczynnikiem przy $r$. Równanie niejednorodne

# %% [markdown]
# $$\ddot r+\frac{k}{m}r=0$$

# %% [markdown]
# rozwiązujemy, tradycyjnie zakładając, że nasze ma rozwiązanie w postaci $r=e^{\lambda t}$. Wtedy otrzymujemy równanie charakterystyczne

# %% [markdown]
# $$\lambda^2+\frac{k}{m}=0,$$

# %% [markdown]
# z którego dostajemy dwa pierwiastki jednokrotne zespolone $\lambda_0\in\left\{\pm i\sqrt\frac{k}{m}\right\}$

# %% [markdown]
# Więc nasze rozwiązanie ogólne będzie w postaci

# %% [markdown]
# $$r=A_r\cos\sqrt\frac{k}{m}t+B_r\sin\sqrt\frac{k}{m}t+g\frac{m}{k}$$

# %% [markdown]
# Pora teraz znaleźć $\theta$. Ten przypadek jest jeszcze prostrzy, ponieważ od razu mamy równanie jednorodnę

# %% [markdown]
# $$\ddot{\theta} +\frac{g}{l}\theta=0$$

# %% [markdown]
# Które rozwiązujemy analogicznie do powyższego otrzymując

# %% [markdown]
# $$\theta = A_\theta\cos\sqrt\frac{g}{l}t + B_\theta\sin\sqrt\frac{g}{l}t$$

# %% [markdown]
# # Rozwiązanie numeryczne

# %% [markdown]
# Zacznijmy najpierw od rozwiązywania numerycznych.

# %% [markdown]
# ## Gauss

# %% [markdown]
# Własnoręcznie zaimplementowaliśmy metodę Gaussa

# %%
import numpy as np

def Gauss(n,dt,u,k=20,m=1,l=1,g=9.81):
    """
    dt - różnica w czasie
    n - liczba punktów w których liczymy
    u - warunki początkowe w kolejności [r,theta,dr,dtheta]
    k - stała sprężystości
    m - masa
    l - długość nierozciągniętej sprężyny
    g - stała grawitacji (by móc się bawić prawami fizyki)
    """
    
    r  =np.zeros(n+1)
    dr =np.zeros(n+1) # pochodna r
    ddr=np.zeros(n+1) # pochodna dr
    
    theta  =np.zeros(n+1)
    dtheta =np.zeros(n+1)
    ddtheta=np.zeros(n+1)
    
    r[0],theta[0],dr[0],dtheta[0]=u
    
    ddr[0]= g * np.cos(dtheta[0])-k/m*r[0]+(l+r[0])*dtheta[0]**2
    ddtheta[0]= (-g*np.sin(theta[0]) - 2*dtheta[0]*dr[0])/(l+r[0])
    
    for i in range(n):
        r[i+1] = r[i]+ dr[i]*dt
        dr[i+1]=dr[i]+ddr[i]*dt
        
        theta[i+1] = theta[i]+ dtheta[i]*dt
        dtheta[i+1]=dtheta[i]+ddtheta[i]*dt
        
        ddr[i+1]= g * np.cos(theta[i])-(k/m)*r[i]+(l+r[i])*dtheta[i]**2
        ddtheta[i+1] = (-g*np.sin(theta[i]) - 2*dtheta[i]*dr[i])/(l+r[i])
        
    return (r,theta)

# %% [markdown]
# Sprawdźmy co do tej pory osiągneliśmy

# %%
l_0=1
r,theta=Gauss(int(1e4),1e-3,[0,np.pi/12,0,0],l=l_0) # 10 sekund co dt=10e-3, gdzie tylko odchylamy od położenie rónowagi (r=0)

# %%
x=(l_0+r[::20])*np.sin(theta[::20])
y=-(l_0+r[::20])*np.cos(theta[::20])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)     # A tuple unpacking to unpack the only plot
line.set_data([],[])
xlim=(min(x)*1.1 if min(x)<0 else min(x)*0.9,max(x)*1.1 if max(x)>0 else max(x)*0.9)
ylim=(min(y)*1.1 if min(y)<0 else min(y)*0.9,max(y)*1.1 if max(y)>0 else max(y)*0.9)

def animate(i):
    plt.clf()
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.plot(x[0:i],y[0:i],'b')
    plt.plot(x[i-1],y[i-1],'ro')
    return (line,)

ani = FuncAnimation(fig, animate, frames=len(x), interval=50,blit=True, )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)     # A tuple unpacking to unpack the only plot
line.set_data([],[])
xlim=(min(x)*1.1 if min(x)<0 else min(x)*0.9,max(x)*1.1 if max(x)>0 else max(x)*0.9)
ylim=(min(y)*1.1 if min(y)<0 else min(y)*0.9,max(y)*1.1 if max(y)>0 else -min(y)/10)

def animate(i):
    plt.clf()
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.plot(x[0:i],y[0:i],'b')
    plt.plot([0,x[i-1]],[0,y[i-1]],'r')
    plt.plot(x[i-1],y[i-1],'ro')
    return (line,)

ani = FuncAnimation(fig, animate, frames=len(x), interval=10,blit=True, )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Ale chyba wszyscy wiemy, że jest ona niedokładna, więc używaliśmy metod zaimplementowanych w pytonie. Ale zanim przjdziemy dalej to możemy porówać obie metody

# %% [markdown]
# ## Porównanie metod numerycznych

# %% [markdown]
# W bibliotece `scipy.integrate` zaimplementowana jest funkcja `solve_ivp`, rozwiązująca równania różniczkowe numerycznie. Podstawowo korzysta ona z metody Runge–Kutta–Fehlberg, która jest znacznie dokładniejsza w długich przedziałach czasu.

# %%
from scipy.integrate import solve_ivp

# %%
def func(t,u):
    r,theta,dr,dtheta = u
    return dr, dtheta, g*np.cos(theta)-k/m*r+(l+r)*dtheta**2, (-g*np.sin(theta) - 2*dtheta*dr)/(l+r)

# %% [markdown]
# Porównując metody przyjeliśmy następujące wartości
#  - $g=9.81\vphantom{\dfrac{}{}}$
#  - $k=20\vphantom{\dfrac{}{}}$
#  - $m =1\vphantom{\dfrac{}{}}$
#  - $l = 1$

# %% [markdown]
# Z warunkami początkowymi
#  - $r = \dfrac{1}{2}\vphantom{\dfrac{}{}}$
#  - $\theta = \dfrac{\pi}{3}\vphantom{\dfrac{}{}}$
#  - $\dot r = 0$
#  - $\dot\theta = 0$

# %% [markdown]
# W czasie 20 sekund z odstępami $\frac{1}{100}$ sekundy

# %%
g=9.81
k=20
m=1
l=1
u=[1/2,np.pi/3,0,0] #warunki początkowe
dt=1/1000 # co ile sprawdzamy
T=10 # przez jaki czas
n=int(T*dt**-1) # ile punktów

# %%
sol_RK=solve_ivp(func,(0,T),u,t_eval=np.linspace(0,T,n+1))

# %%
r_RK=sol_RK.y[0]
theta_RK=sol_RK.y[1]
x_RK=(l+r_RK)*np.sin(theta_RK)
y_RK=-(l+r_RK)*np.cos(theta_RK)

# %%
r_Gauss,theta_Gauss=Gauss(n,dt,u)

# %%
x_Gauss=(l+r_Gauss)*np.sin(theta_Gauss)
y_Gauss=-(l+r_Gauss)*np.cos(theta_Gauss)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.plot(x_RK[:n//3],y_RK[:n//3])

# %%
# %matplotlib inline
plt.plot(x_Gauss[:n//3],y_Gauss[:n//3])

# %% [markdown]
# Na pierwszy rzut oka widać niewielkie różnice, porównajmy je na jednym animacji

# %%
from matplotlib.animation import FuncAnimation

# %matplotlib notebook

fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)     # A tuple unpacking to unpack the only plot
line.set_data([],[])
xlim=(min(*x_RK,*x_Gauss)*1.1 if min(*x_RK,*x_Gauss)<0 else min(*x_RK,*x_Gauss)*0.9,max(*x_RK,*x_Gauss)*1.1 if max(*x_RK,*x_Gauss)>0 else max(*x_RK,*x_Gauss)*0.9)
ylim=(min(*y_RK,*y_Gauss)*1.1 if min(*y_RK,*y_Gauss)<0 else min(*y_RK,*y_Gauss)*0.9,max(*y_RK,*y_Gauss)*1.1 if max(*y_RK,*y_Gauss)>0 else max(*y_RK,*y_Gauss)*0.9)
step=30 # co ile wyświetlać


def animate(i):
    plt.clf()
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.plot(x_RK[0:i*step:step],y_RK[0:i*step:step],'b')
    plt.plot(x_RK[step*(i-1)],y_RK[step*(i-1)],'bo')
    plt.plot(x_Gauss[0:i*step:step],y_Gauss[0:i*step:step],'r')
    plt.plot(x_Gauss[step*(i-1)],y_Gauss[step*(i-1)],'ro')


    return (line,)

ani = FuncAnimation(fig, animate, frames=len(x_RK)//step, interval=50,blit=True )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Możemy zauważyć, że z czasem nasze rozwiązania się coraz bardzie różnią, ale która metoda jest lepsza? Uprośćmy delikatnie sytuację, mianowicie, niech

# %% [markdown]
# $$r = \dot r = \theta = \dot\theta= 0$$

# %% [markdown]
# Czyli na nierozciągniętą sprężynę zawieszamy w jednej chwili ciężarek, wtedy

# %%
u=[0,0,0,0]

# %%
sol_RK=solve_ivp(func,(0,T),u,t_eval=np.linspace(0,T,n+1))

# %%
r_Gauss,theta_Gauss=Gauss(n,dt,u)
r_RK=sol_RK.y[0]

# %% [markdown]
# Porównajmy teraz o ile nasze sprężyny się rozciągnęły w kolejnych punktach

# %%
# %matplotlib inline
plt.plot(r_Gauss)
plt.plot(r_RK)

# %% [markdown]
# Intuicyjnie, jeśli nałozymy na sprężyne w stanie spoczynku (nierozciągniętą) jakąś masę to jej amplituda powinna być stała, a nawet się zmniejszać, jeśli uwzględnimy działenie sił takich jak opory powietrza, naprężenia wewnętrzne itp. Używając metody Runge-Kutty otrzymujemy taki wynik, natomiast używająć metody Gaussa to sprężyna zwiększa swoje maksymalne wychylenia zwiększając swoją energię maksymalną, co jest sprzeczne z prawami fizyki (układ izolowany).

# %% [markdown]
# Na poniższych wykresach widać dokładnie, że oscylacje są coraz większe przy użyciu metody Gaussa, i stałe przy metodzie R-K

# %%
# %matplotlib inline
plt.plot(r_Gauss)
plt.title("Metoda Gaussa")
plt.plot([0,n+1],[max(r_Gauss),max(r_Gauss)],'grey')
plt.plot([0,n+1],[min(r_Gauss),min(r_Gauss)],'grey')

# %%
# %matplotlib inline
plt.plot(r_RK)
plt.title("Metoda Runge-Kutty")
plt.plot([0,n+1],[max(r_RK),max(r_RK)],'grey')
plt.plot([0,n+1],[min(r_RK),min(r_RK)],'grey')

# %% [markdown]
# ## Porównanie rozwiązania liniowego

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# \ddot{r}= g \cos\theta - \frac{k}{m}r+(l+r)\dot\theta^2 \vphantom{\sqrt\frac{k}{m}}\\
# \ddot{\theta}(l+r) = -g\sin\theta - 2 \dot\theta\dot{r} \vphantom{\sqrt\frac{k}{m}}
# \end{array} \right.
# \quad\quad\text{VS}\quad\quad
# \left\{ \begin{array}{l}
#   r=A_r\cos\sqrt\frac{k}{m}t +  B_r\sin\sqrt\frac{k}{m}t+\frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)\frac{gml}{kl-4gm}\cos\left(2\sqrt\frac{g}{l}t\right) -A_\theta B_\theta\frac{gml}{kl-4gm}\sin\left(2\sqrt\frac{g}{l}t\right) + \frac{mg}{k}\left(1+A_\theta^2 +  B_\theta^2\right)\\
# \theta = A_\theta\cos\sqrt\frac{g}{l}t + B_\theta\sin\sqrt\frac{g}{l}t
# \end{array} \right.
# $$

# %% [markdown]
# Na początku porównajmy $r$ w obu równaniach i osobno $\theta$-ty, dla poniższych wartości

# %% [markdown]
#  - $g=9.81\vphantom{\dfrac{}{}}$
#  - $k=50\vphantom{\dfrac{}{}}$
#  - $m =\frac{1}{10}\vphantom{\dfrac{}{}}$
#  - $l = 1$<br>

# %% [markdown]
# Z warunkami początkowymi
#  - $r = r_0= \frac{l}{10}\vphantom{\dfrac{}{}}$
#  - $\theta =\theta_0= \frac{\pi}{12}\vphantom{\dfrac{}{}}$
#  - $\dot r =\dot r_0= 0$
#  - $\dot\theta =\dot\theta_0= 0$

# %%
import numpy as np
g=9.81
k=10
m=1
l=1

r_0=l/10
theta_0=np.pi/12
dr_0=0
dtheta_0=0

# %% [markdown]
# Czyli mamy wartości początkowe dla $r$ oraz $\theta$-ty. Możemy teraz znaleźć stałe $A$ oraz $B$. Ponieważ stałe dla $\theta$-ty występują również w rozwiązaniu $r$-a, zacznijmy od niej

# %% [markdown]
# ### Znalezienie stałych dla $r$ stare

# %% [markdown]
# $$r_0=r(0) = A_r\cos\sqrt\frac{k}{m}0+B_r\sin\sqrt\frac{k}{m}0+g\frac{m}{k} = A_r +g\frac{m}{k}$$<br>
# Zatem

# %%
A_r=r_0-g*m/k
A_r
# Out:
# -0.8810000000000001

# %% [markdown]
# Wiemy jeszcze, że $\dot r(0) =\dot r_0$, zatem<br>
# $$\dot r =\frac{\text d}{\text dt}\left(\vphantom{\frac{\text d}{\text dt}}A_r\cos\sqrt\frac{k}{m}t+B_r\sin\sqrt\frac{k}{m}t+g\frac{m}{k}\right) = -A_r\sqrt\frac{k}{m}\sin\sqrt\frac{k}{m}t+B_r\sqrt\frac{k}{m}\cos\sqrt\frac{k}{m}t$$<br>

# %% [markdown]
# Zatem <br>
# $$\dot r_0=\dot r(0) = B_r\sqrt\frac{k}{m}$$<br>
# Co nam daje $$B_r = \dot r_0 \sqrt\frac{m}{k}$$

# %%
B_r=dr_0*(m/k)**(1/2)
B_r
# Out:
# 0.0

# %% [markdown]
# ### Znalezienie stałych dla $\theta$

# %% [markdown]
# Analogicznie jak dla $r$ przyrównujemy
# $$\theta_0 = \theta(0) = A_\theta\cos\sqrt\frac{g}{l}0 + B_\theta\sin\sqrt\frac{g}{l}0 = A_\theta$$

# %%
A_theta=theta_0
A_theta
# Out:
# 0.2617993877991494

# %% [markdown]
# Oraz korzystamy z drugiego warunku początkowego, czyli $\dot\theta = \dot\theta_0 $

# %% [markdown]
# $$\dot\theta = \frac{\text d}{\text dt}\left(\vphantom{\frac{\text d}{\text dt}}A_\theta\cos\sqrt\frac{g}{l}t + B_\theta\sin\sqrt\frac{g}{l}t\right) = -A_\theta\sqrt\frac{g}{l}\sin\sqrt\frac{g}{l}t + B_\theta\sqrt\frac{g}{l}\cos\sqrt\frac{g}{l}t$$

# %% [markdown]
# Zatem

# %% [markdown]
# $$ \dot\theta_0 = \dot\theta(0) = B_\theta\sqrt\frac{g}{l}$$

# %% [markdown]
# Co podobnie jak dla $r$-a daje nam
# $$ B_\theta = \dot\theta_0\sqrt\frac{l}{g} $$

# %%
B_theta=dtheta_0*(l/g)**(1/2)
B_theta
# Out:
# 0.0

# %% [markdown]
# ### Znalezienie stałych dla $r$

# %% [markdown]
# Analogicznie jak dla $\theta$-ty

# %% [markdown]
#  $$r_0=A_r +\frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)\frac{gml}{kl-4gm} + \frac{mg}{k}\left(1+A_\theta^2 +  B_\theta^2\right)$$

# %% [markdown]
# Zatem

# %% [markdown]
# $$A_r = r_0 -\frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)\frac{gml}{kl-4gm} - \frac{mg}{k}\left(1+A_\theta^2 +  B_\theta^2\right)$$

# %%
A_r=r_0-1/2*(A_theta**2+B_theta**2)*g*m*l/(k*l-4*g*m)-m*g/k*(1+A_theta**2+B_theta**2)
A_r
# Out:
# -0.9367392996844698

# %% [markdown]
# $$r=A_r\cos\sqrt\frac{k}{m}t +  B_r\sin\sqrt\frac{k}{m}t+\frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)\frac{gml}{kl-4gm}\cos\left(2\sqrt\frac{g}{l}t\right) -A_\theta B_\theta\frac{gml}{kl-4gm}\sin\left(2\sqrt\frac{g}{l}t\right) + \frac{mg}{k}\left(1+A_\theta^2 +  B_\theta^2\right)$$

# %% [markdown]
# Znamy jeszcze drugi warunek początkowy $\dot r = \dot r_0$

# %% [markdown]
# $$ \dot r_0 = B_r\sqrt\frac{k}{m}-A_\theta B_\theta\frac{gml}{kl-4gm}\sqrt\frac{g}{l}$$

# %% [markdown]
# Zatem

# %% [markdown]
# $$B_r= \left(\dot r_0+A_\theta B_\theta\frac{gml}{kl-4gm}\sqrt\frac{g}{l}\right)\sqrt\frac{m}{k}$$

# %%
B_r=(dr_0+A_theta*B_theta*g*m*l/(k*l-4*g*m)*(g/l)**2)*(m/k)**(1/2)
B_r
# Out:
# 0.0

# %% [markdown]
# ### Porównanie  na wykresach

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import numpy as np
u=[r_0, theta_0, dr_0, dtheta_0]

# %%
from scipy.integrate import solve_ivp
def func(t,u):
    r,theta,dr,dtheta = u
    return dr, dtheta, g*np.cos(theta)-k/m*r+(l+r)*dtheta**2, (-g*np.sin(theta) - 2*dtheta*dr)/(l+r)

# %%
T=np.linspace(0,10,1000)
sol=solve_ivp(func,(0,10),u,t_eval=T)

# %%
r=sol.y[0]
theta=sol.y[1]

# %% [markdown]
# Zacznijmy od porównania wartości dla $r$

# %% [markdown]
# $$r=A_r\cos\sqrt\frac{k}{m}t +  B_r\sin\sqrt\frac{k}{m}t+\frac{1}{2}\left(A_\theta^2 +  B_\theta^2\right)\frac{gml}{kl-4gm}\cos\left(2\sqrt\frac{g}{l}t\right) -A_\theta B_\theta\frac{gml}{kl-4gm}\sin\left(2\sqrt\frac{g}{l}t\right) + \frac{mg}{k}\left(1+A_\theta^2 +  B_\theta^2\right)$$

# %%
r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)
              +B_r*np.sin((k/m)**(1/2)*t)
              +1/2*(A_theta**2+B_theta**2)*g*m*l/(k*l-4*g*m)*np.cos(2*(g/l)**(1/2)*t)
              -A_theta*B_theta*g*m*l/(k*l-4*g*m)*np.sin(2*(g/l)**(1/2)*t)
              +m*g/k*(1+A_theta**2+B_theta**2)
              for t in T]) # Chyba najlepsze

# %%
r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)+
              B_r*np.sin((k/m)**(1/2)*t)+
              B_theta*l*m*(g*l)**(1/2)/(k*l-g*m)*np.cos((g/l)**(1/2)*t)-
              A_theta*m*l*(g*l)**(1/2)/(k*l-g*m)*np.sin((g/l)**(1/2)*t)+
              g*m/k
              for t in T]) #r_liniowe

# %%
r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)+
              B_r*np.sin((k/m)**(1/2)*t)+
              B_theta*l*m*(g*l)**(1/2)/(k*l-g*m)*np.cos((g/l)**(1/2)*t)-
              A_theta*m*l*(g*l)**(1/2)/(k*l-g*m)*np.sin((g/l)**(1/2)*t)+
              g**2*m**2/k/(g*m-k*l)-g*l*m/(g*m-k*l)
              for t in T]) #r_liniowe

# %%
r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)
              +B_r*np.sin((k/m)**(1/2)*t)
              +B_theta*(g*l)**(1/2)/(k/m-g/l)*np.cos((g/l)**(1/2)*t)
              -A_theta*(g*l)**(1/2)/(k/m-g/l)*np.sin((g/l)**(1/2)*t)
              +g*m/k for t in T]) #r_liniowe

# %%
r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)
              +B_r*np.sin((k/m)**(1/2)*t)
              +B_theta*l**2*m*np.cos((g/l)**(1/2)*t)/(k*l-g*m)
              -A_theta*l**2*m*np.sin((g/l)**(1/2)*t)/(k*l-g*m)
              +g*l*m/(k*l-g*m)-g**2*m**2/(k*(k*l-g*m))
              for t in T]) #r_liniowe

# %%
r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)
              +B_r*np.sin((k/m)**(1/2)*t)
              +B_theta*l**2*m*np.cos((g/l)**(1/2)*t)/(k*l-g*m)#*(g/l)**(1/2)
              -A_theta*l**2*m*np.sin((g/l)**(1/2)*t)/(k*l-g*m)#*(g/l)**(1/2)
              +g*l*m/(k*l-g*m)-g**2*m**2/(k*(k*l-g*m))
              for t in T]) #r_liniowe

# %%
# %matplotlib inline
plt.plot(r,'b',label="Rzeczywiste")
plt.plot(r_l,'r',label="Linowe")
plt.legend(loc="best")

# %% [markdown]
# Widzimy, że wyniki rzeczywiste i uproszczone (liniowe) są bardzo podobne do siebie. Sprawdźmy jak wygląda sytuacja dla $\theta$

# %%
theta_l=np.array([A_theta*np.cos((g/l)**(1/2)*t)+B_theta*np.sin((g/l)**(1/2)*t) for t in T])

# %%
# %matplotlib inline
plt.plot(theta,'b',label="Rzeczywiste")
plt.plot(theta_l,'r',label="Linowe")
plt.legend(loc="best")

# %% [markdown]
# I tu widzimy ogromne różnice w wyniku. Zobaczmy jak wygląda to na animacji

# %%
x=(l+r)*np.sin(theta)
y=-(l+r)*np.cos(theta)

x_l=(l+r_l)*np.sin(theta_l)
y_l=-(l+r_l)*np.cos(theta_l)

# %%
from matplotlib.animation import FuncAnimation

# %matplotlib notebook

fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)
line.set_data([],[])
xlim=(min(*x,*x_l)*1.1 if min(*x,*x_l)<0 else min(*x,*x_l)*0.9,max(*x,*x_l)*1.1 if max(*x,*x_l)>0 else max(*x,*x_l)*0.9)
ylim=(min(*y,*y_l)*1.1 if min(*y,*y_l)<0 else min(*y,*y_l)*0.9,max(*y,*y_l)*1.1 if max(*y,*y_l)>0 else max(*y,*y_l)*0.9)


def animate(i):
    plt.clf()
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.plot(x[0:i],y[0:i],'b')
    plt.plot(x[i-1],y[i-1],'bo')
    plt.plot(x_l[0:i],y_l[0:i],'r')
    plt.plot(x_l[i-1],y_l[i-1],'ro')


    return (line,)

ani = FuncAnimation(fig, animate, frames=len(x), interval=50,blit=True )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
from matplotlib.animation import FuncAnimation

# %matplotlib notebook

fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)
line.set_data([],[])
xlim=(min(*x,*x_l)*1.1 if min(*x,*x_l)<0 else min(*x,*x_l)*0.9,max(*x,*x_l)*1.1 if max(*x,*x_l)>0 else max(*x,*x_l)*0.9)
ylim=(min(*y,*y_l)*1.1 if min(*y,*y_l)<0 else min(*y,*y_l)*0.9,max(*y,*y_l)*1.1 if max(*y,*y_l)>0 else -min(*y,*y_l)/10)


def animate(i):
    plt.clf()
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.plot(x[0:i],y[0:i],'b')
    plt.plot(x[i-1],y[i-1],'bo')
    plt.plot(x_l[0:i],y_l[0:i],'r')
    plt.plot(x_l[i-1],y_l[i-1],'ro')
    plt.plot([0,x[i-1]],[0,y[i-1]],'gray')
    plt.plot([0,x_l[i-1]],[0,y_l[i-1]],'gray')



    return (line,)

ani = FuncAnimation(fig, animate, frames=len(x), interval=50,blit=True )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Jeśli przyjżymy się równaniu liniowemu które rozwiązaliśmy

# %% [markdown]
# $$
# \left\{ \begin{array}{l}
# \ddot{r}= g - \frac{k}{m}r\\
# \ddot{\theta} = -\frac{g}{l}\theta
# \end{array} \right.
# \quad\quad \text{VS}\quad\quad
# \left\{ \begin{array}{l}
# \ddot{r}= g \cos\theta - \frac{k}{m}r+(l+r)\dot\theta^2 \vphantom{\sqrt\frac{k}{m}}\\
# \ddot{\theta}(l+r) = -g\sin\theta - 2 \dot\theta\dot{r} \vphantom{\sqrt\frac{k}{m}}
# \end{array} \right.
# $$

# %% [markdown]
# zauważymy, że $r$ oraz $\theta$ są niezależne od siebie. Jeśli uznamy, że $m\ll k$, wtedy po prawej stronie pierwszego równania możemy zaniedbać wszystko oprócz składnika $-\frac{k}{m}r$, co jak się zaraz okaże wystarczy by przybliżenie liniowe było dokładne.

# %% [markdown]
# ### Wykresy dla różnych wartości $\dfrac{m}{k}$

# %%
l=1
g=9.81
r_0=l/10
theta_0=np.pi/12
dr_0=0
dtheta_0=0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-555c2563754b> in <module>
#       2 g=9.81
#       3 r_0=l/10
# ----> 4 theta_0=np.pi/12
#       5 dr_0=0
#       6 dtheta_0=0
#
# NameError: name 'np' is not defined

# %%
m=1/10
k=50

# %%
T=np.linspace(0,10,1000)

A_r=r_0-g*m/k
B_r=dr_0*(m/k)**(1/2)
A_theta=theta_0
B_theta=dtheta_0*(l/g)**(1/2)

r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)+B_r*np.sin((k/m)**(1/2)*t)+g*m/k for t in T]) #r_liniowe
theta_l=np.array([A_theta*np.cos((g/l)**(1/2)*t)+B_theta*np.sin((g/l)**(1/2)*t) for t in T])

sol=solve_ivp(func,(0,10),u,t_eval=T)
r=sol.y[0]
theta=sol.y[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-81112542bd00> in <module>
#       9 theta_l=np.array([A_theta*np.cos((g/l)**(1/2)*t)+B_theta*np.sin((g/l)**(1/2)*t) for t in T])
#      10
# ---> 11 sol=solve_ivp(func,(0,10),u,t_eval=T)
#      12 r=sol.y[0]
#      13 theta=sol.y[1]
#
# NameError: name 'solve_ivp' is not defined

# %%
# %matplotlib inline
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('m=1/10,  k=50')

ax1.plot(r,'b',label="Rzeczywiste")
ax1.plot(r_l,'r',label="Linowe")
ax1.legend(loc="best")

ax2.plot(theta,'b',label="Rzeczywiste")
ax2.plot(theta_l,'r',label="Linowe")
ax2.legend(loc="best")

fig.set_size_inches(20, 7, forward=True)

# %%
m=1
k=50

# %%
T=np.linspace(0,10,1000)

A_r=r_0-g*m/k
B_r=dr_0*(m/k)**(1/2)
A_theta=theta_0
B_theta=dtheta_0*(l/g)**(1/2)

r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)+B_r*np.sin((k/m)**(1/2)*t)+g*m/k for t in T]) #r_liniowe
theta_l=np.array([A_theta*np.cos((g/l)**(1/2)*t)+B_theta*np.sin((g/l)**(1/2)*t) for t in T])

sol=solve_ivp(func,(0,10),u,t_eval=T)
r=sol.y[0]
theta=sol.y[1]

# %%
# %matplotlib inline
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('m=1,  k=50')

ax1.plot(r,'b',label="Rzeczywiste")
ax1.plot(r_l,'r',label="Linowe")
ax1.legend(loc="best")

ax2.plot(theta,'b',label="Rzeczywiste")
ax2.plot(theta_l,'r',label="Linowe")
ax2.legend(loc="best")

fig.set_size_inches(20, 7, forward=True)

# %%
m=1
k=10

# %%
T=np.linspace(0,10,1000)

A_r=r_0-g*m/k
B_r=dr_0*(m/k)**(1/2)
A_theta=theta_0
B_theta=dtheta_0*(l/g)**(1/2)

r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)+B_r*np.sin((k/m)**(1/2)*t)+g*m/k for t in T]) #r_liniowe
theta_l=np.array([A_theta*np.cos((g/l)**(1/2)*t)+B_theta*np.sin((g/l)**(1/2)*t) for t in T])

sol=solve_ivp(func,(0,10),u,t_eval=T)
r=sol.y[0]
theta=sol.y[1]

# %%
# %matplotlib inline
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('m=1,  k=10')

ax1.plot(r,'b',label="Rzeczywiste")
ax1.plot(r_l,'r',label="Linowe")
ax1.legend(loc="best")

ax2.plot(theta,'b',label="Rzeczywiste")
ax2.plot(theta_l,'r',label="Linowe")
ax2.legend(loc="best")

fig.set_size_inches(20, 7, forward=True)

# %% [markdown]
# ### Animacja

# %%
import numpy as np
T_span=np.linspace(0,10,5000)
def func2(t,u):
    r,theta,dr,dtheta,k= u
    return dr, dtheta, g*np.cos(theta)-k/m*r+(l+r)*dtheta**2, (-g*np.sin(theta) - 2*dtheta*dr)/(l+r), 0

# %%
sol=solve_ivp(func2,(0,10),u+[100],t_eval=T_span)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a321f609a3fd> in <module>
# ----> 1 sol=solve_ivp(func2,(0,10),u+[100],t_eval=T_span)
#
# NameError: name 'solve_ivp' is not defined

# %%
from matplotlib.animation import FuncAnimation
plt.style.use('dark_background')

# %matplotlib notebook

fig, (ax1, ax2) = plt.subplots(1, 2)
n=5
mk_ratio=[1/i**2 for i in range(1,n)[::-1]] + [i**2 for i in range(1,n)]
fig.set_size_inches(12, 3, forward=True)

m=1
def animate(i):
    
    k=(i/30+1/10)**3
    
    
    fig.suptitle('m=1,   k='+'{0:.3g}'.format(k))
    
    A_r=r_0-g*m/k
    B_r=dr_0*(m/k)**(1/2)
    A_theta=theta_0
    B_theta=dtheta_0*(l/g)**(1/2)

    r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)+B_r*np.sin((k/m)**(1/2)*t)+g*m/k for t in T_span]) #r_liniowe
    theta_l=np.array([A_theta*np.cos((g/l)**(1/2)*t)+B_theta*np.sin((g/l)**(1/2)*t) for t in T_span])

    sol=solve_ivp(func2,(0,10),u+[k],t_eval=T_span)
    r=sol.y[0]
    theta=sol.y[1]
    
    
    ax1.cla()
    ax2.cla()
    
    ax1.plot(r,'b',label="Rzeczywiste")
    ax1.plot(r_l,'r',label="Linowe")
    ax1.legend(loc=2)

    ax2.plot(theta,'b',label="Rzeczywiste")
    ax2.plot(theta_l,'r',label="Linowe")

    fig.show()

    return (0,)

ani = FuncAnimation(fig, animate, frames=200, interval=100 )

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4bcc12bb3a4e> in <module>
#       1 from matplotlib.animation import FuncAnimation
# ----> 2 plt.style.use('dark_background')
#       3
#       4 get_ipython().run_line_magic('matplotlib', 'notebook')
#       5
#
# NameError: name 'plt' is not defined

# %%
animate(1)
# Out:
# (0,)

# %%
from matplotlib.animation import FuncAnimation
plt.style.use('dark_background')

# %matplotlib notebook

fig, (ax1, ax2) = plt.subplots(1, 2)
n=5
mk_ratio=[1/i**2 for i in range(1,n)[::-1]] + [i**2 for i in range(1,n)]
fig.set_size_inches(12, 3, forward=True)

m=1
def animate(i):
    
    k=(i/30+1/10)**3
    
    
    fig.suptitle('m=1,   k='+'{0:.3g}'.format(k))
    
    A_theta=theta_0
    B_theta=dtheta_0*(l/g)**(1/2)
    
    A_r=r_0-1/2*(A_theta**2+B_theta**2)*g*m*l/(k*l-4*g*m)-m*g/k*(1+A_theta**2+B_theta**2)
    B_r=(dr_0+A_theta*B_theta*g*m*l/(k*l-4*g*m)*(g/l)**2)*(m/k)**(1/2)
   
    r_l=np.array([A_r*np.cos((k/m)**(1/2)*t)
              +B_r*np.sin((k/m)**(1/2)*t)
              +1/2*(A_theta**2+B_theta**2)*g*m*l/(k*l-4*g*m)*np.cos(2*(g/l)**(1/2)*t)
              -A_theta*B_theta*g*m*l/(k*l-4*g*m)*np.sin(2*(g/l)**(1/2)*t)
              +m*g/k*(1+A_theta**2+B_theta**2)
              for t in T_span]) # Chyba najlepsze
    theta_l=np.array([A_theta*np.cos((g/l)**(1/2)*t)+B_theta*np.sin((g/l)**(1/2)*t) for t in T_span])


    sol=solve_ivp(func2,(0,10),u+[k],t_eval=T_span)
    r=sol.y[0]
    theta=sol.y[1]
    
    
    ax1.cla()
    ax2.cla()
    
    ax1.plot(r,'b',label="Rzeczywiste")
    ax1.plot(r_l,'r',label="Linowe")
    ax1.legend(loc=2)

    ax2.plot(theta,'b',label="Rzeczywiste")
    ax2.plot(theta_l,'r',label="Linowe")

    fig.show()

    return (0,)

ani = FuncAnimation(fig, animate, frames=200, interval=100 )

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="864">

# %% [markdown]
# Możemy zauważyć, że dla małych wartości $k$ nasze $r$ zachowuje się tak samo jak liniowe przybliżenie, natomiast natomiast kątach nie możemy zawuażyć podobieństwa.<br>
# Zwiększając współczynnik $k$ $\left(\frac{k}{m}\right)$ rozwiązania dla promieni zaczynają się rozjeżdżać, natomiast kąty się do siebie zbliżają.<br>
# Jeśli dalej będziemy zwiększać $k$ to w pewnym momencie wartości $r$ zaczą się spowrtorem do siebie zbliżać tak samo jak to ciągle robią wartości wychylenia. Od pewnego momentu wartości $r$ oraz $\theta$ będą bardzo blisko swoich liniowych przybliżeń (Według nas, jeśli $\frac{k}{m}\geq 150$). Niestety zwiększając ten współczynnik zmniejszamy możliwość rozciągania się sprężyny, więc zbliżamy się do zwykłego rozwiązania wahadła prostego, które otrzymamy, jeśli przejdziemy z $k\to\infty$

# %% [markdown]
# # Doświadczenie

# %% [markdown]
# Początkowo doświadczenie prowadziliśmy dla dwóch sprężyn, oraz trzech ciał oraz jednej diody.

# %% [markdown]
# ## stała sprężystości

# %% [markdown]
# Pomiary dla poszczególnych ciał

# %% [markdown]
# | Ciało       | Oznaczenie Masy | Masa    | Oznaczenie Długości 1| Długość sprężyny 1|Oznaczenie Długości 2| Długość sprężyny 2|
# | ---         | ---             | ---     | ---                  | ---               |   ---               | ---               |
# | Jeden       | $m_1$           | 51.20 g | $l_{11}$             | 39.6 cm           | $l_{21}$            | 53.4 cm           |
# | Dwa         | $m_2$           | 118.23 g| $l_{12}$             | 52.3 cm           | $l_{22}$            | 65.5 cm           |
# | Trzy        | $m_3$           | 84.75 g | $l_{13}$             | 45.6 cm           | $l_{23}$            | 58.2 cm           |
# | Dwa + Trzy  | $m_4$           | 202.98 g| $l_{14}$             | 67.9 cm           | $l_{24}$            | 87.2 cm           |
# | Dioda       | $m_d$           | 2.42 g  | -                    |       -           | -                   | -                 |
# | Sprężyna 1  | $m_{s_1}$       | 63 g    | $l_{s_1}$            | 32.1 cm           | -                   | -                 |
# | Sprężyna 2  | $m_{s_2}$       | 96 g    | -                    | -                 |  $l_{s_2}$          | 51.4cm           |

# %%
m1=51.2e-3
m2=118.23e-3
m3=84.75e-3
m4=m2+m3
md=2.42e-3
ms1=63e-3
ms2=96e-3

# %%
m4
# Out:
# 0.20298

# %%
l11 = 39.6e-2
l12 = 52.3e-2
l13 = 45.6e-2
l14 = 67.9e-2

l21 = 53.4e-2
l22 = 65.5e-2
l23 = 58.2e-2
l24 = 87.2e-2

ls1 = 32.1e-2
ls2 = 51.4e-2

# %% [markdown]
# Teraz potrzebujemy wyliczyś stałe sprężystości $k_1$ oraz $k_2$. By tego dokonać posłużyliśmy się wzorem
# $$ F = kx$$
# gdzie
# - F - siła działająca na sprężynę
# - k - stała sprężystośći
# - x - zmiana długości ciała

# %% [markdown]
# W naszym przypadku na sprężynę działa tylko siła ciężkości ciała, więc
# $$ k_i = \frac{m_{j}g}{l_{ij}-l_{s_i}} \quad\forall_{j},$$
# gdzie
#  - $k$ - stała sprężystości
#  - $m_j$ - masa $j$-tego ciała
#  - $g$ - przyciąganie ziemskie
#  - $l_{ij}$ - długość $i$-tej sprężyny po nałożeniu $j$-tego ciała
#  - $l_{s_i}$ - długość $i$-tej sprężyny bez małożonego ciężaru <br>
#
# zatem

# %%
g=9.81

# %%
i=1
for j in range(1,5):
    exec("print(m"+str(j)+"*g/(l"+str(i)+str(j)+"-ls"+str(i)+"))" )
# Out:
# 6.69696
# 5.741763861386138
# 6.1585
# 5.562105586592178

# %%
i=2
for j in range(1,5):
    exec("print(m"+str(j)+"*g/(l"+str(i)+str(j)+"-ls"+str(i)+"))" )
# Out:
# 25.11359999999998
# 8.225789361702127
# 12.226433823529423
# 5.562105586592179

# %% [markdown]
# Druga sprężyna miała wadę fabryczną (zbyt gęsto zwinięte zwoje, przy małych ciężarach w ogóle się nie rozciągała) więc stała znacząco się różniła w zależności od ciała. Dlatego będziemy operowali tylko na pierwszym ciele i przyjmiemy, że
# $$k=k_1=6$$
# $$l_1=l_{11}$$
# $$\cdots$$

# %%
k=6
l0=ls1
l1=l11
l2=l12
l3=l13
l4=l14

# %% [markdown]
# ## Obliczenia

# %%
from scipy.integrate import solve_ivp
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import math
plt.style.use('dark_background')

# %matplotlib inline

# %%
k=k1=6
l=l0
g=9.81
m=m2

# %%
def func(t,u):
    r,theta,dr,dtheta = u
    return dr, dtheta, g*np.cos(theta)-k/m*r+(l+r)*dtheta**2, (-g*np.sin(theta) - 2*dtheta*dr)/(l+r)

# %%
sol=solve_ivp(func,(0,30),[0,np.pi/12,0,0],t_eval=np.linspace(0,30,1000))

# %%
x=(sol.y[0]+l)*np.sin(sol.y[1])
y=-(sol.y[0]+l)*np.cos(sol.y[1])

# %%
# %matplotlib notebook

fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)     # A tuple unpacking to unpack the only plot
line.set_data([],[])
ax.set_xlim(min(x)*1.1,max(x)*1.1)
ax.set_ylim(min(y)*1.1 if min(y)<0 else min(y)*0.9,max(y)*1.1 if max(y)>0 else max(y)*0.9)

def animate(i):
    line.set_data(x[0:i],y[0:i])
    return (line,)

ani = FuncAnimation(fig, animate, frames=len(x), interval=50,blit=True, )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib notebook

fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)     # A tuple unpacking to unpack the only plot
line.set_data([],[])
xlim=(min(x)*1.1 if min(x)<0 else min(x)*0.9,max(x)*1.1 if max(x)>0 else max(x)*0.9)
ylim=(min(y)*1.1 if min(y)<0 else min(y)*0.9,max(y)*1.1 if max(y)>0 else max(y)*0.9)

def animate(i):
    plt.clf()
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.plot(x[0:i],y[0:i],'b')
    plt.plot(x[i-1],y[i-1],'ro')
    return (line,)

ani = FuncAnimation(fig, animate, frames=len(x), interval=50,blit=True )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib notebook

fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)     # A tuple unpacking to unpack the only plot
line.set_data([],[])
xlim=(min(x)*1.1 if min(x)<0 else min(x)*0.9,max(x)*1.1 if max(x)>0 else max(x)*0.9)
ylim=(min(y)*1.1 if min(y)<0 else min(y)*0.9,max(y)*1.1 if max(y)>0 else 0.1)

def animate(i):
    plt.clf()
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.plot(x[0:i],y[0:i],'b')
    plt.plot(x[i-1],y[i-1],'ro')
    plt.plot([0,x[i-1]],[0,y[i-1]],'r')
    return (line,)

ani = FuncAnimation(fig, animate, frames=len(x), interval=100,blit=True )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
sol=solve_ivp(func,(0,30),[l2-l0,0,0,0],t_eval=np.linspace(0,30,1000))

# %%
x=(sol.y[0]+l)*np.sin(sol.y[1])
y=-(sol.y[0]+l)*np.cos(sol.y[1])

# %%
# %matplotlib notebook

fig, ax = plt.subplots()
line, = ax.plot([],[],lw=2)     # A tuple unpacking to unpack the only plot
line.set_data([],[])
xlim=(min(x)*1.1 if min(x)<0 else min(x)*0.9,max(x)*1.1 if max(x)>0 else max(x)*0.9)
ylim=(min(y)*1.1 if min(y)<0 else min(y)*0.9,max(y)*1.1 if max(y)>0 else -min(y)/10)

def animate(i):
    plt.clf()
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.plot(x[0:i],y[0:i],'b')
    plt.plot(x[i-1],y[i-1],'ro')
    plt.plot([0,x[i-1]],[0,y[i-1]],'r')
    return (line,)

ani = FuncAnimation(fig, animate, frames=len(x), interval=100,blit=True )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Jeśli na początku nie wychylimy ciała, i rozciągniemy sprężynę jedynie ciężarem ciała (stan spoczynkowy), to ruch ciała jest ledwie zauważalne, wynikający jedynie z błędów pomiarowych i przybliżonej wartości $k$. Zatem to jest kolejna rzecz, która która potwierdza, że prawdopodobnie przyjeliśmy dobry model.

# %% [markdown]
# ## Porównanie z eksperymentem

# %% [markdown]
# W pierwszym eksperymentcie użyliśmy drugiego ciała z przyczepioną diodą, pierwszej sprężyny. Ciało odchylono na około $12^\circ$, _próbując_ nie rozciągnąć sprężyny. Czas badania ruchy wynosił 32 sekund.

# %%
g=9.81
l=l0
m=m2+md+0.99e-3 #ostatnie to masa taśmy klejącej
k=k1
T=32

# %%
sol=solve_ivp(func,(0,T),[0.05,-np.pi/12,0,0],t_eval=np.linspace(0,T,1000))

# %%
x=(sol.y[0]+l)*np.sin(sol.y[1])
y=-(sol.y[0]+l)*np.cos(sol.y[1])

# %%
plt.style.use('dark_background')

# %matplotlib inline
plt.axes().set_aspect('equal')
plt.plot(x,y)
plt.savefig(r"pliki\wykres\a3.png")

# %% [markdown]
# <table><tr>
# <td> <img src="pliki\wykres\a3.png" alt="Drawing" style="width: 600px;"/> </td>
# <td> <img src="pliki\RRwT\32s_0_12.jpg" alt="Drawing" style="width: 400px;"/> </td>
# </tr></table>

# %% [markdown]
# Widzimy pewne podobieństwa, ale obrazy się widocznie różnią, ale jeśli zwiększyy delikatnie warunki początkowe, rozciągając sprężynę o dodatkowe 5cm to otrzymamy

# %%
plt.style.use('dark_background')

sol=solve_ivp(func,(0,T),[0.05+0.05,-np.pi/12,0,0],t_eval=np.linspace(0,T,1000))

x=(sol.y[0]+l)*np.sin(sol.y[1])
y=-(sol.y[0]+l)*np.cos(sol.y[1])

# %matplotlib inline
plt.axes().set_aspect('equal')
plt.plot(x,y)
plt.savefig(r"pliki\wykres\a4.png")

# %% [markdown]
# Gdzie podobieństwo zdecydowanie jest zauważalne

# %% [markdown]
# <table><tr>
# <td> <img src="pliki\wykres\a4.png" alt="Drawing" style="width: 600px;"/> </td>
# <td> <img src="pliki\RRwT\32s_0_12.jpg" alt="Drawing" style="width: 400px;"/> </td>
# </tr></table>

# %% [markdown]
# Spróbujmy jeszcze zrobić to samo ze sprężyną rozciągniętą na długość $l_2$

# %%
plt.style.use('dark_background')

sol=solve_ivp(func,(0,T),[l2-l,-np.pi/12,0,0],t_eval=np.linspace(0,T,1000))

x=(sol.y[0]+l)*np.sin(sol.y[1])
y=-(sol.y[0]+l)*np.cos(sol.y[1])

# %matplotlib inline
plt.axes().set_aspect('equal')
plt.plot(x,y)
plt.savefig(r"pliki\wykres\a5.png")

# %% [markdown]
# <table><tr>
# <td> <img src="pliki\wykres\a5.png" alt="Drawing" style="width: 600px;"/> </td>
# <td> <img src="pliki\RRwT\32s_l1_12.jpg" alt="Drawing" style="width: 400px;"/> </td>
# </tr></table>

# %% [markdown]
# Tutaj również widzimy podobieństwa. Zważając na trudności związane z nieznanymi dokładnymi warunkami początkowymi oraz pominięcie wszystkich zewnętrznych sił (przykładowo ugięcie pręta, na którym była zawieszona sprężyna), wydaje się, że nasz model jest poprawny

# %% [markdown]
# ## Tor ruchu innych dośwadczeń

# %% [markdown]
# <table><tr>
# <td> <img src="pliki\RRwT\a1.jpg" alt="Drawing" style="width: 400px;"/> </td>
# <td> <img src="pliki\RRwT\a2.jpg" alt="Drawing" style="width: 400px;"/> </td>
# <td> <img src="pliki\RRwT\a3.jpg" alt="Drawing" style="width: 400px;"/> </td>
# </tr>
# <tr>
# <td> <img src="pliki\RRwT\a4.jpg" alt="Drawing" style="width: 400px;"/> </td>
# <td> <img src="pliki\RRwT\b1.jpg" alt="Drawing" style="width: 400px;"/> </td>
# <td> <img src="pliki\RRwT\b2.jpg" alt="Drawing" style="width: 400px;"/> </td>
# </tr></table>

# %% [markdown]
# W folderze <a href="pliki/RRwT">RRwT</a> znajdują się pozostałe dośwadczenia, oraz zdjęcia z wagami poszczególnych ciał.

# %% [markdown]
# # Bibliografia

# %% [markdown]
# - <a href="https://link.springer.com/content/pdf/10.1007/BF01231426.pdf">Periodic solutions of a spring-pendulum system</a> - R Broucke & P. A. Baxa
#
# - <a href="https://www.researchgate.net/profile/Meirielen-De-Sousa-2/publication/316187700_Energy_Distribution_in_Spring_Pendulums/links/598cb052aca272e57ad1a9e2/Energy-Distribution-in-Spring-Pendulums.pdf">Energy Distribution in Spring Pendulums</a> - M. C. de Sousa
#
# - <a href="https://aapt.scitation.org/doi/pdf/10.1119/1.1677269">An improved calculation of the mass for the resonant spring pendulum</a> - Joseph Christensen
#
# - <a href="https://scholar.ptuk.edu.ps/bitstream/123456789/626/1/41-%20The%20Fractional%20Model%20of%20Spring%20Pendulum-%20New%20Features%20within%20Different%20Kernels.pdf">THE FRACTIONAL MODEL OF SPRING PENDULUM:
# NEW FEATURES WITHIN DIFFERENT KERNELS</a> - D. BALEANU, Jihad H. ASAD, A. JAJARMI
#
# - <a href="https://primo.bg.pwr.edu.pl/primo_library/libweb/action/display.do?tabs=detailsTab&ct=display&fn=search&doc=48TUR_TUR01000135880&indx=5&recIds=48TUR_TUR01000135880&recIdxs=4&elementId=4&renderMode=poppedOut&displayMode=full&frbrVersion=&frbg=&&vl(1UI0)=contains&dscnt=0&scp.scps=scope%3A%2848TUR_ibuk%29%2Cscope%3A%2848TUR_TUR03%29%2Cscope%3A%2848TUR_TUR01%29%2Cscope%3A%2848TUR_dlibra%29%2Cscope%3A%2848TUR_ejournals%29%2Cscope%3A%2848TUR_nasbi%29%2Cprimo_central_multiple_fe&tb=t&vid=48TUR_VIEW&mode=Basic&srt=rank&tab=all_tab&dum=true&vl(freeText0)=Mechanika%20Taylor&dstmp=1641651539693">Mechanika klasyczna. 1</a> - John Robert Taylor, Wyd. 1, Warszawa, Wydawnictwo Naukowe PWN, 2006, IBSN 978-83-01-14673-3
#
# - <a href="https://primo.bg.pwr.edu.pl/primo_library/libweb/action/display.do?tabs=detailsTab&ct=display&fn=search&doc=48TUR_TUR01000135888&indx=4&recIds=48TUR_TUR01000135888&recIdxs=3&elementId=3&renderMode=poppedOut&displayMode=full&frbrVersion=&frbg=&&vl(1UI0)=contains&dscnt=0&scp.scps=scope%3A%2848TUR_ibuk%29%2Cscope%3A%2848TUR_TUR03%29%2Cscope%3A%2848TUR_TUR01%29%2Cscope%3A%2848TUR_dlibra%29%2Cscope%3A%2848TUR_ejournals%29%2Cscope%3A%2848TUR_nasbi%29%2Cprimo_central_multiple_fe&tb=t&vid=48TUR_VIEW&mode=Basic&srt=rank&tab=all_tab&dum=true&vl(freeText0)=Mechanika%20Taylor&dstmp=1641651539693">Mechanika klasyczna. 2</a> - John Robert Taylor, Wyd. 1, Warszawa, Wydawnictwo Naukowe PWN, 2006, IBSN 978-83-01-15039-6
#
# - <a href="http://www.if.pwr.edu.pl/~amitus/">Fizyka Układów Prostych - Wykłady</a> - prof. Antoni C. Mituś
#
# - <a href="https://en.wikipedia.org/wiki/Main_Page">Wikipiedia</a> - Jimmy Wales
#
# - <a href="http://www.sp2zdwola.vline.net.pl/pliki/nauczanie_zdalne/6b_jpolski_z1_25-29.05.2020.pdf">Narodziny świata</a> - Jan Parandowski
# (do nazw `commit`'ów)
